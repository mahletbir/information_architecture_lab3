# %%
import pandas as pd
import requests
import json
import base64
import s3fs # documentation: https://s3fs.readthedocs.io/en/latest/
import time
import twitter_keys
# Out:
# /Users/atreish/opt/anaconda3/lib/python3.7/site-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.8) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
####################
#Group 1: Atreish Ramlakhan, Avigdor Skidelsky, Yuxiao Shen

#####################


# %config IPCompleter.greedy=True


key_secret = '{}:{}'.format(twitter_keys.client_key, twitter_keys.client_secret).encode('ascii')
b64_encoded_key = base64.b64encode(key_secret)
b64_encoded_key = b64_encoded_key.decode('ascii')

#identify base url and oauth token path
base_url = 'https://api.twitter.com/' #base url for authentication
auth_url = '{}oauth2/token'.format(base_url)

#share header information -- encoding is ascii
auth_headers = {
    'Authorization': 'Basic {}'.format(b64_encoded_key),
    'Content-Type': 'application/x-www-form-urlencoded;charset=UTF-8'
}

#pass clientcredentials
auth_data = {
    'grant_type': 'client_credentials'
}

#send authentication using requests - POST request
auth_resp = requests.post(auth_url, headers=auth_headers, data=auth_data)

#check response status. 200 = OK
auth_resp.status_code
# Out:
# 200

# %%
#Keys in data response are token_type (bearer) and access_token (your access token)
print(auth_resp.json().keys())

access_token = auth_resp.json()['access_token']


search_headers = {
    'Authorization': 'Bearer {}'.format(access_token)    
}

#enter search parameters for coronavirus example. This looks for "covid-19" in the 1000 most recent tweets
query_params = {
    'q': 'covid-19',
    'result_type': 'recent',
    'count': 100, #update here to get more/less than 1000 returns
    'lang': 'en' #filters by english language only
}


#identify search url path and save 
search_url = '{}1.1/search/tweets.json'.format(base_url)


#run search using get request
search_resp = requests.get(search_url, headers=search_headers, params=query_params)

#check status code of GET request
search_resp.status_code
# Out:
# dict_keys(['token_type', 'access_token'])
# 200

# %%
#print text from result to verify  
twitter_data = search_resp.json()

for x in twitter_data['statuses']:
    print(x['text'] + '\n')
    break #prints after one iteration and stops, remove break to see all 1000
# Out:
# RT @BLABBERMOUTHNET: JUDAS PRIEST Cancels Lowell, Massachusetts Concert Due To Non-COVID-19-Related Illness https://t.co/QcelHUT2iH https:/…

# %%
# move data into data frame 
df = pd.DataFrame(twitter_data['statuses'])

# show one record to verify import 
df.head(1)
# Out:
#                        created_at                   id               id_str  \
# 0  Tue Apr 05 00:43:48 +0000 2022  1511142527625474048  1511142527625474048
#
#                                                 text  truncated  \
# 0  RT @BLABBERMOUTHNET: JUDAS PRIEST Cancels Lowe...      False
#
#                                             entities  \
# 0  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                             metadata  \
# 0  {'iso_language_code': 'en', 'result_type': 're...
#
#                                               source  in_reply_to_status_id  \
# 0  <a href="https://mobile.twitter.com" rel="nofo...                    NaN
#
#   in_reply_to_status_id_str  ...  retweet_count favorite_count favorited  \
# 0                      None  ...              4              0     False
#
#   retweeted possibly_sensitive lang extended_entities quoted_status_id  \
# 0     False              False   en               NaN              NaN
#
#   quoted_status_id_str  quoted_status
# 0                  NaN            NaN
#
# [1 rows x 30 columns]

# %%
# we can use pandas to put data directly into an s3 bucket
#prepare csv file name   
filename = 's3/lab3-group1'#specify location of s3:/{my-bucket}/
groupname= 'Lab_3_Group_1' #name of your group
datetime = time.strftime("%Y%m%d%H%M%S") #timestamp
filenames3 = "%s%s%s.csv"%(filename,groupname,datetime) #name of the filepath and csv file

#encoding must be adjusted to accommodate abnormal characters. Use s3fs to write to S3 bucket
byte_encoded_df = df.to_csv(None).encode() #encodes file as binary

s3 = s3fs.S3FileSystem(anon=False)
with s3.open(filenames3, 'wb') as file:
    file.write(byte_encoded_df) #writes byte-encoded file to s3 location

#print success message
print("Successfull uploaded file to location:"+str(filenames3))
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/s3fs/core.py in _call_s3(self, method, *akwarglist, **kwargs)
#     260             try:
# --> 261                 out = await method(**additional_kwargs)
#     262                 return out
#
# ~/opt/anaconda3/lib/python3.7/site-packages/aiobotocore/client.py in _make_api_call(self, operation_name, api_params)
#     224             error_class = self.exceptions.from_code(error_code)
# --> 225             raise error_class(parsed_response, operation_name)
#     226         else:
#
# ClientError: An error occurred (InvalidBucketName) when calling the PutObject operation: The specified bucket is not valid.
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-10-4aff88185f11> in <module>
#      11 s3 = s3fs.S3FileSystem(anon=False)
#      12 with s3.open(filenames3, 'wb') as file:
# ---> 13     file.write(byte_encoded_df) #writes byte-encoded file to s3 location
#      14
#      15 #print success message
#
# ~/opt/anaconda3/lib/python3.7/site-packages/fsspec/spec.py in __exit__(self, *args)
#    1661
#    1662     def __exit__(self, *args):
# -> 1663         self.close()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/fsspec/spec.py in close(self)
#    1628         else:
#    1629             if not self.forced:
# -> 1630                 self.flush(force=True)
#    1631
#    1632             if self.fs is not None:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/fsspec/spec.py in flush(self, force)
#    1499                 raise
#    1500
# -> 1501         if self._upload_chunk(final=force) is not False:
#    1502             self.offset += self.buffer.seek(0, 2)
#    1503             self.buffer = io.BytesIO()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/s3fs/core.py in _upload_chunk(self, final)
#    1960
#    1961         if self.autocommit and final:
# -> 1962             self.commit()
#    1963         return not final
#    1964
#
# ~/opt/anaconda3/lib/python3.7/site-packages/s3fs/core.py in commit(self)
#    1981                     Body=data,
#    1982                     ACL=self.acl,
# -> 1983                     **self.kwargs,
#    1984                 )
#    1985             else:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/s3fs/core.py in _call_s3(self, method, *kwarglist, **kwargs)
#    1827
#    1828     def _call_s3(self, method, *kwarglist, **kwargs):
# -> 1829         return self.fs.call_s3(method, self.s3_additional_kwargs, *kwarglist, **kwargs)
#    1830
#    1831     def _initiate_upload(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/fsspec/asyn.py in wrapper(*args, **kwargs)
#      89     def wrapper(*args, **kwargs):
#      90         self = obj or args[0]
# ---> 91         return sync(self.loop, func, *args, **kwargs)
#      92
#      93     return wrapper
#
# ~/opt/anaconda3/lib/python3.7/site-packages/fsspec/asyn.py in sync(loop, func, timeout, *args, **kwargs)
#      69         raise FSTimeoutError from return_result
#      70     elif isinstance(return_result, BaseException):
# ---> 71         raise return_result
#      72     else:
#      73         return return_result
#
# ~/opt/anaconda3/lib/python3.7/site-packages/fsspec/asyn.py in _runner(event, coro, result, timeout)
#      23         coro = asyncio.wait_for(coro, timeout=timeout)
#      24     try:
# ---> 25         result[0] = await coro
#      26     except Exception as ex:
#      27         result[0] = ex
#
# ~/opt/anaconda3/lib/python3.7/site-packages/s3fs/core.py in _call_s3(self, method, *akwarglist, **kwargs)
#     279                 err = e
#     280         err = translate_boto_error(err)
# --> 281         raise err
#     282
#     283     call_s3 = sync_wrapper(_call_s3)
#
# OSError: [Errno 22] The specified bucket is not valid.
